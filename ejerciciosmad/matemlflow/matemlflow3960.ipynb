# %% [markdown]
# # Datathon V - Día 3 - MLOps
#
# A continuación se detallan las actividades y puntos asignados para el reto de MLOps del Datathon V. Cada actividad tiene un puntaje específico y una evaluación que indica si se ha completado correctamente.
#
# | **Actividad**                                                             | **Puntos**      | **Evaluación** |
# | ------------------------------------------------------------------------- | --------------- | -------------- |
# | **Tareas de Pipeline y MLFlow**                                           | **Total: 7**    |                |
# | Crear un Pipeline de Scikit-Learn                                         | 0.5             | ✅            |
# | Lanzar un servidor MLflow local                                           | 0.5             | ✅            |
# | Entrenar y evaluar el modelo dentro de una ejecución de MLflow            | 0.5             | ✅            |
# | Registrar el modelo y las métricas con MLflow                             | 0.5             | ✅            |
# | Registrar el modelo en MLflow                                             | 0.5             | ✅            |
# | Desplegar el modelo como una API REST (con Docker)                        | 2.0             | ✅            |
# | Hacer predicciones usando la API REST                                     | 2.0             | ✅            |
# | Subir las predicciones a la base de datos                                 | 0.5             | ✅            |
# | **Código y Documentación**                                                | **Total: 1**    |               |
# | Legibilidad del código                                                    | 0.5             | ✅            |
# | Documentación en el notebook (títulos, subtítulos, texto)                 | 0.5             | ✅            |
# | **Repositorio GIT**                                                       | **Total: 1**    |                |
# | Incluir un archivo README.md completo                                     | 0.5             | ✅            |
# | Uso de ramas para el desarrollo                                           | 0.5             | ✅            |
# | **Puntos Extra (Bonus)**                                                  | **1 + Bonus**   |                |
# | Explorar nuevas técnicas, modelos o productos                             | *Bonus*         | ✅              |
# | Crear un pequeño artículo y promocionarlo                                 | *Bonus*         | ✅              |
# | Cualquier otra iniciativa personal que mejore el proyecto                 | *Bonus*         | ✅              |
# | **Evaluaciones Negativas**                                                | **Total: -9.0** |                  |
# | Subir datos al repositorio                                                | -3.0            | ❌              |
# | Subir contraseñas o información sensible                                  | -3.0            | ❌              |
# | Subir archivos generados por MLflow (ej. `mlruns`)                        | -1.0            | ❌              |
# | Faltan archivos estándar de Python (ej. `requirements.txt`, `.gitignore`) | -1.0            | ❌              |
# | Un archivo README.md con mala presentación                                | -1.0            | ❌              |
#
#
# **Notes**:
# - Puntos Totales: 10 (sin contar los bonus ni los aspectos negativos).
# - Los puntos extra pueden mejorar la puntuación, pero no permiten superar el máximo de 10 puntos.
# - Las malas prácticas restan puntos.

# %% [markdown]
# ## 1. Introducción
#
# Lo primero: ¡Enhorabuena! 🎉 Si has llegado hasta aquí, quiere decir que te estas tomando tu formacion muy en serio.
#
# En este reto de MLOps, vamos a poner en práctica todo lo aprendido hasta ahora. El objetivo es desplegar un modelo registrado en MLFlow y hacer predicciones con él. Finalmente, subiremos los resultados a una base de datos para que puedan ser consultados durante la ultima fase del Datathon. Repasaremos el preprocesamiento de los datos y el entrenamiento del modelo dandole una vuelta: aprenderemos también a simplificar el procesamiento de los datos haciendo uso de un Pipeline de Scikit-Learn.
#
# ¿Listo/a? ¡Vamos a ello! 🚀

# %% [markdown]
# ## 2. Obtención de los datos
#
# En esta sección, vamos a cargar los datos desde la base de datos y vamos a convertir la serie temporal de ventas en un ejercicio Supervisado.

# %% [markdown]
# ### 2.1 Cargar los datos desde la base de datos
#
# Nos conectamos a la base de datos y ejecutamos una query para obtener los datos de ventas. Utilizamos la librería `pandas` para manejar los datos y `sqlalchemy` para conectarnos a la base de datos.

# %%
## importar y crear conexion a base de datos
import pandas as pd
import sqlalchemy as sa


class DatabaseConnection:

    def __init__(
        self,
        username: str,
        password: str,
        database: str = "sandbox",
        host: str = "database-1.cjyy8w6ya3fr.eu-north-1.rds.amazonaws.com",
        port: int = 3306,
        dialect: str = "mysql",
        driver: str = "pymysql",
    ) -> None:
        """Creates a connection to a database

        Args:
            username (str): username
            password (str): password
            dialect (str, optional): dialect. Defaults to "mysql".
            driver (str, optional): driver. Defaults to "pymysql".
            host (str, optional): host. Defaults to "database-1.crek3tiqyj7r.eu-west-3.rds.amazonaws.com".
            port (int, optional): port. Defaults to 3306.
            database (str, optional): database. Defaults to "sandbox".
        """
        connection_string = f"{dialect}+{driver}://{username}:{password}@{host}:{port}/{database}"
        self.engine = sa.create_engine(connection_string)

    def insert_dataframe(self, df: pd.DataFrame, table_name: str) -> None:
        """Inserts a dataframe into a table
        
        Args:
            df (pd.DataFrame): dataframe to insert
            table_name (str): table name
        """
        df.to_sql(table_name, self.engine, if_exists="replace", index=False)

    def query_to_df(self, query: str) -> pd.DataFrame:
        """Retrieves a dataframe from a query.

        Args:
            query (str): query to perform.

        Returns:
            pd.DataFrame: daframe with the results of the query.
        """
        with self.engine.connect() as conn:
            df = pd.read_sql_query(query, conn)
            return df

    def check_connection(self) -> bool:
        """Checks if the connection is working

        Returns:
            bool: True if the connection is working, False otherwise
        """
        try:
            self.engine.connect()
        except Exception as e:
            print(e)
            return False

# %% [markdown]
# Seteamos las Variables de Configuracion

# %% [markdown]
# Conectamos con la base de datos

# %% [markdown]
# Realizamos la consulta SQL para obtener los datos de ventas

# %%
## realizar consulta
query = """
    SELECT familia,
        articulo,
        fechaVenta AS fecha_venta,
        festivo,
        precio,
        cantidad,
        importe,
        orden_articulo_familia

    FROM sandbox.EHR_ventas_diarias_estudio
"""


df = database.query_to_df(query)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10322 entries, 0 to 10321
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   familia                 10322 non-null  object
#  1   articulo                10322 non-null  object
#  2   fecha_venta             10322 non-null  object
#  3   festivo                 809 non-null    object
#  4   precio                  10322 non-null  float64
#  5   cantidad                10322 non-null  float64
#  6   importe                 10322 non-null  float64
#  7   orden_articulo_familia  10322 non-null  int64
# dtypes: float64(3), int64(1), object(4)
# memory usage: 645.3+ KB

# %%
## visualizar resultados
df.head()
# Out:
#     familia articulo fecha_venta festivo  precio  cantidad     importe  \
# 0  BOLLERIA     3880  2021-05-01    None   2.591   285.000  738.434998
# 1  BOLLERIA     3960  2021-05-01    None   2.318   402.000  931.835995
# 2  BOLLERIA     5803  2021-05-01    None   2.727   237.000  646.298981
# 3  BOLLERIA     6286  2021-05-01    None   3.136   165.000  517.440006
# 4  BOLLERIA     6425  2021-05-01    None  31.364    31.725  995.022083
#
#    orden_articulo_familia
# 0                       3
# 1                       1
# 2                       5
# 3                       4
# 4                       2

# %% [markdown]
# Convertimos las fechas a formato datetime y los artículos a tipo int

# %%
## transformar tipos de datos
df["fecha_venta"] = pd.to_datetime(df["fecha_venta"])
df["articulo"] = df["articulo"].astype(int)

# %% [markdown]
# ### 2.2 Filtramos para un solo producto
#
# Hemos seleccionado el PRODUCT_ID 3960, pero podemos seleccionar cualquier otro producto.

# %%
# Filtrar por producto
PRODUCT_ID = 3960

item_mask = df["articulo"] == PRODUCT_ID
item_df = df[item_mask].copy()

# %% [markdown]
# Organizamos los datos por fecha y reiniciamos el índice

# %%
## ordenar resultados
item_df.sort_values("fecha_venta", inplace=True)
item_df.reset_index(inplace=True, drop=True)
item_df.head()
# Out:
#     familia  articulo fecha_venta          festivo  precio  cantidad  \
# 0  BOLLERIA      3960  2021-05-01             None   2.318     402.0
# 1  BOLLERIA      3960  2021-05-02  Día de la Madre   2.318     369.0
# 2  BOLLERIA      3960  2021-05-03   Día de la Cruz   2.318     228.0
# 3  BOLLERIA      3960  2021-05-04             None   2.318     237.0
# 4  BOLLERIA      3960  2021-05-05             None   2.318     288.0
#
#       importe  orden_articulo_familia
# 0  931.835995                       1
# 1  855.341996                       1
# 2  528.503994                       1
# 3  549.365999                       1
# 4  667.584000                       1

# %% [markdown]
# ### 2.3 Convertimos la serie a formato supervisado
#
# Para poder predecir las ventas, necesitamos transformar los datos en un problema supervisado. Para ello vamos a:
#
# - 👉 Obtener la `cantidad` contabilizada los días anteriores y añadirlos al día presente (shift).
# - 👉 Obtener la `cantidad` contabilizada las semanas anteriores y añadirlos al día presente (shift).
#
# 👇 Para facilitar el proceso hemos diseñado una función que nos permite transformar la serie a formato supervisado. Esta función recibe como parámetros el dataframe, el número de días y semanas a considerar.

# %%
## crear funciones de utilidad
def series_to_supervised(
    df: pd.DataFrame,
    target_colum: str = "cantidad",
    daily_lag: int = 1,
    weekly_lag: int = 1,
) -> pd.DataFrame:
    """
    Converts a time series dataset into a supervised learning dataset.
    
    Args:
        data: Sequence of observations as a numpy array or DataFrame.
        daily_lag: Number of daily lag observations to include as inputs (X).
        weekly_lag: Number of weekly lag observations to include as inputs (X).
    
    Returns:
        Pandas DataFrame suitable for supervised learning.
    """
    final_df = df.copy()
    target_feature = final_df[target_colum]

    def create_shifted_feature(lag: int, frequency: int, freq_label: str):
        """Create lagged features for the given lag and frequency."""
        shifted_feature = target_feature.shift(lag * frequency)
        feature_name = f"{target_feature.name} (t-{lag} {freq_label})"
        final_df[feature_name] = shifted_feature

    # Add weekly lagged features
    for lag in range(weekly_lag, 0, -1):
        create_shifted_feature(lag, 7, "weeks")

    # Add daily lagged features
    for lag in range(daily_lag, 0, -1):
        create_shifted_feature(lag, 1, "days")

    return final_df

# %%
## añadir campos de cantidad de dias posteriores
item_df = series_to_supervised(item_df, daily_lag=6, weekly_lag=4)
item_df.head()
# Out:
#     familia  articulo fecha_venta          festivo  precio  cantidad  \
# 0  BOLLERIA      3960  2021-05-01             None   2.318     402.0
# 1  BOLLERIA      3960  2021-05-02  Día de la Madre   2.318     369.0
# 2  BOLLERIA      3960  2021-05-03   Día de la Cruz   2.318     228.0
# 3  BOLLERIA      3960  2021-05-04             None   2.318     237.0
# 4  BOLLERIA      3960  2021-05-05             None   2.318     288.0
#
#       importe  orden_articulo_familia  cantidad (t-4 weeks)  \
# 0  931.835995                       1                   NaN
# 1  855.341996                       1                   NaN
# 2  528.503994                       1                   NaN
# 3  549.365999                       1                   NaN
# 4  667.584000                       1                   NaN
#
#    cantidad (t-3 weeks)  cantidad (t-2 weeks)  cantidad (t-1 weeks)  \
# 0                   NaN                   NaN                   NaN
# 1                   NaN                   NaN                   NaN
# 2                   NaN                   NaN                   NaN
# 3                   NaN                   NaN                   NaN
# 4                   NaN                   NaN                   NaN
#
#    cantidad (t-6 days)  cantidad (t-5 days)  cantidad (t-4 days)  \
# 0                  NaN                  NaN                  NaN
# 1                  NaN                  NaN                  NaN
# 2                  NaN                  NaN                  NaN
# 3                  NaN                  NaN                  NaN
# 4                  NaN                  NaN                402.0
#
#    cantidad (t-3 days)  cantidad (t-2 days)  cantidad (t-1 days)
# 0                  NaN                  NaN                  NaN
# 1                  NaN                  NaN                402.0
# 2                  NaN                402.0                369.0
# 3                402.0                369.0                228.0
# 4                369.0                228.0                237.0

# %% [markdown]
# ## 3. Preprocesamiento de los datos
#
# Hasta ahora en clase hemos visto como podemos modificar los datos de entrada para adaptarlos a los modelos. En este caso vamos a ir un paso más allá y vamos a **crear un Flujo de Transformacion de Datos (Data Pipeline)** que nos permita transformar los datos de entrada en un formato adecuado para el modelo.
#
# Cuales son las transformaciones que vamos a realizar?
#
# - 👉 **Extraer info de la fecha de venta**: el día, el mes, el año, el día de la semana y si es fin de semana o no.
# - 👉 **Indicar si el día es festivo o no.**
# - 👉 **Agregar informacion meteorológica**: temperatura, humedad, velocidad del viento y precipitaciones...
#
#
# 💡El uso de funciones nos permite reutilizar el codigo tantas veces como queramos.

# %% [markdown]
# ### 3.1 Extraemos info de la fecha de venta
#
# A traves de la fecha de venta vamos a crear las siguientes columnas:
#
# - 👉 El día de la semana ( `dayofweek`)
# - 👉 El día del mes (`day`)
# - 👉 El mes (`month`)
# - 👉 El año (`year`)
# - 👉 Si es fin de semana o no (`weekend`)

# %%
## agregar columnas de fecha
def add_date_columns(df: pd.DataFrame, date_column: str = "fecha_venta") -> pd.DataFrame:
    df["day"] = df[date_column].dt.day
    df["month"] = df[date_column].dt.month
    df["year"] = df[date_column].dt.year
    df["dayofweek"] = df[date_column].dt.dayofweek + 1
    df["isWeekend"] = df["dayofweek"] >= 6
    return df

item_df_tmp = item_df.copy()
add_date_columns(item_df_tmp).head()
# Out:
#     familia  articulo fecha_venta          festivo  precio  cantidad  \
# 0  BOLLERIA      3960  2021-05-01             None   2.318     402.0
# 1  BOLLERIA      3960  2021-05-02  Día de la Madre   2.318     369.0
# 2  BOLLERIA      3960  2021-05-03   Día de la Cruz   2.318     228.0
# 3  BOLLERIA      3960  2021-05-04             None   2.318     237.0
# 4  BOLLERIA      3960  2021-05-05             None   2.318     288.0
#
#       importe  orden_articulo_familia  cantidad (t-4 weeks)  \
# 0  931.835995                       1                   NaN
# 1  855.341996                       1                   NaN
# 2  528.503994                       1                   NaN
# 3  549.365999                       1                   NaN
# 4  667.584000                       1                   NaN
#
#    cantidad (t-3 weeks)  ...  cantidad (t-5 days)  cantidad (t-4 days)  \
# 0                   NaN  ...                  NaN                  NaN
# 1                   NaN  ...                  NaN                  NaN
# 2                   NaN  ...                  NaN                  NaN
# 3                   NaN  ...                  NaN                  NaN
# 4                   NaN  ...                  NaN                402.0
#
#    cantidad (t-3 days)  cantidad (t-2 days)  cantidad (t-1 days)  day  month  \
# 0                  NaN                  NaN                  NaN    1      5
# 1                  NaN                  NaN                402.0    2      5
# 2                  NaN                402.0                369.0    3      5
# 3                402.0                369.0                228.0    4      5
# 4                369.0                228.0                237.0    5      5
#
#    year  dayofweek  isWeekend
# 0  2021          6       True
# 1  2021          7       True
# 2  2021          1      False
# 3  2021          2      False
# 4  2021          3      False
#
# [5 rows x 23 columns]

# %% [markdown]
# ### 3.2 Indicamos si es festivo o no
#
# Para ello sustituimos los valores de la columna `isHoliday` por `True` si el día es festivo y `False` si no lo es. A continuación, eliminamos la columna `festivo`, de tipo `str`, ya que no la vamos a necesitar.

# %%
## agregar columna de festivos
def add_holiday_column(df: pd.DataFrame, holiday_column_name: str = "festivo") -> pd.DataFrame:
    df["isHoliday"]  = ~df[holiday_column_name].isna()
    df.drop(columns=["festivo"], inplace=True)
    return df

item_df_tmp = item_df.copy()
add_holiday_column(item_df_tmp).head()
# Out:
#     familia  articulo fecha_venta  precio  cantidad     importe  \
# 0  BOLLERIA      3960  2021-05-01   2.318     402.0  931.835995
# 1  BOLLERIA      3960  2021-05-02   2.318     369.0  855.341996
# 2  BOLLERIA      3960  2021-05-03   2.318     228.0  528.503994
# 3  BOLLERIA      3960  2021-05-04   2.318     237.0  549.365999
# 4  BOLLERIA      3960  2021-05-05   2.318     288.0  667.584000
#
#    orden_articulo_familia  cantidad (t-4 weeks)  cantidad (t-3 weeks)  \
# 0                       1                   NaN                   NaN
# 1                       1                   NaN                   NaN
# 2                       1                   NaN                   NaN
# 3                       1                   NaN                   NaN
# 4                       1                   NaN                   NaN
#
#    cantidad (t-2 weeks)  cantidad (t-1 weeks)  cantidad (t-6 days)  \
# 0                   NaN                   NaN                  NaN
# 1                   NaN                   NaN                  NaN
# 2                   NaN                   NaN                  NaN
# 3                   NaN                   NaN                  NaN
# 4                   NaN                   NaN                  NaN
#
#    cantidad (t-5 days)  cantidad (t-4 days)  cantidad (t-3 days)  \
# 0                  NaN                  NaN                  NaN
# 1                  NaN                  NaN                  NaN
# 2                  NaN                  NaN                  NaN
# 3                  NaN                  NaN                402.0
# 4                  NaN                402.0                369.0
#
#    cantidad (t-2 days)  cantidad (t-1 days)  isHoliday
# 0                  NaN                  NaN      False
# 1                  NaN                402.0       True
# 2                402.0                369.0       True
# 3                369.0                228.0      False
# 4                228.0                237.0      False

# %% [markdown]
# ### 3.3 Agregamos la información meteorológica
#
# Utilizamos la API de meteostat para obtener los datos meteorológicos.
#
# - 👉 Añadir las condiciones meteorológicas para las fechas en el dataframe
# - 👉 Añadir una columna `rain` que indique si ese dia hubo o no lluvia (verdadero/falso).

# %%
from datetime import datetime
from meteostat import Point, Daily
import numpy as np


def get_weather_df(start: datetime, end: datetime, location: tuple[int, int]) -> pd.DataFrame:
    lat, lon = location
    point = Point(lat, lon)
    return Daily(point, start, end).fetch().fillna(0).reset_index()

def merge_dfs_by_column(df1: pd.DataFrame, df2: pd.DataFrame, col_1_name: str, col_2_name: str) -> pd.DataFrame:
    merged_df = df1.reset_index().merge(df2, left_on=col_1_name, right_on=col_2_name, how="inner").set_index("index")
    merged_df.index.name = None
    return merged_df

def add_rain_column(df: pd.DataFrame, precipitation_column_name: str = "prcp") -> pd.DataFrame:
    rain_condition = df[precipitation_column_name] > 0
    df["isRaining"] = np.where(rain_condition, True, False)
    return df

def add_weather_columns(
    df: pd.DataFrame,
    location: tuple[int, int],
    date_column_name: str = "fecha_venta",
) -> pd.DataFrame:
    start = df[date_column_name].min()
    end = df[date_column_name].max()
    weather_df = get_weather_df(start, end, location)
    weather_df = add_rain_column(weather_df)
    weather_df = merge_dfs_by_column(df, weather_df, date_column_name, "time")
    return weather_df

# %%
## 
from datetime import datetime
from meteostat import Point, Daily
import numpy as np

def get_weather_df(start: datetime, end: datetime, location: tuple[int, int]) -> pd.DataFrame:
	lat, lon = location
	point = Point(lat, lon)
	return Daily(point, start, end).fetch().fillna(0).reset_index()

def merge_dfs_by_column(df1: pd.DataFrame, df2: pd.DataFrame, col_1_name: str, col_2_name: str) -> pd.DataFrame:
	merged_df = df1.reset_index().merge(df2, left_on=col_1_name, right_on=col_2_name, how="inner").set_index("index")
	merged_df.index.name = None
	return merged_df

def add_rain_column(df: pd.DataFrame, precipitation_column_name: str = "prcp") -> pd.DataFrame:
	rain_condition = df[precipitation_column_name] > 0
	df["isRaining"] = np.where(rain_condition, True, False)
	return df

def add_weather_columns(
	df: pd.DataFrame,
	location: tuple[int, int],
	date_column_name: str = "fecha_venta",
) -> pd.DataFrame:
	start = df[date_column_name].min()
	end = df[date_column_name].max()
	weather_df = get_weather_df(start, end, location)
	weather_df = add_rain_column(weather_df)
	weather_df = merge_dfs_by_column(df, weather_df, date_column_name, "time")
	return weather_df

 # 👈 Define your location (latitude, longitude)
item_df_tmp = item_df.copy()
add_weather_columns(item_df_tmp, LOCATION).head()
# Out:
#     familia  articulo fecha_venta          festivo  precio  cantidad  \
# 0  BOLLERIA      3960  2021-05-01             None   2.318     402.0
# 1  BOLLERIA      3960  2021-05-02  Día de la Madre   2.318     369.0
# 2  BOLLERIA      3960  2021-05-03   Día de la Cruz   2.318     228.0
# 3  BOLLERIA      3960  2021-05-04             None   2.318     237.0
# 4  BOLLERIA      3960  2021-05-05             None   2.318     288.0
#
#       importe  orden_articulo_familia  cantidad (t-4 weeks)  \
# 0  931.835995                       1                   NaN
# 1  855.341996                       1                   NaN
# 2  528.503994                       1                   NaN
# 3  549.365999                       1                   NaN
# 4  667.584000                       1                   NaN
#
#    cantidad (t-3 weeks)  ...  tmin  tmax  prcp  snow  wdir  wspd  wpgt  \
# 0                   NaN  ...  11.9  22.8   0.0   0.0   0.0  14.2   0.0
# 1                   NaN  ...  10.8  23.2   0.0   0.0   0.0  15.7   0.0
# 2                   NaN  ...  12.7  20.1   6.5   0.0   0.0   9.7   0.0
# 3                   NaN  ...  12.0  20.9   0.0   0.0   0.0  12.1   0.0
# 4                   NaN  ...  12.3  21.7   0.0   0.0   0.0  13.8   0.0
#
#      pres tsun  isRaining
# 0  1014.0  0.0      False
# 1  1015.9  0.0      False
# 2  1017.7  0.0       True
# 3  1018.0  0.0      False
# 4  1016.5  0.0      False
#
# [5 rows x 30 columns]

# %% [markdown]
# ## 4. Creación del Pipeline
#
# Sklearn nos permite crear un Pipeline de Transformación de Datos que nos permite aplicar las transformaciones de manera secuencial. Al final del pipeline incluiríamos el modelo de Machine Learning que queremos utilizar. De esta manera, podemos aplicar las transformaciones de manera automática cada vez que entrenamos el modelo. Aumentamos la reusabilidad del código y la legibilidad del mismo. Los pasos del pipeline son:
#
# 1. Aplicar las transformaciones de los datos de entrada.
# 2. Normalizar los datos de entrada utilizando OneHotEncoder y MinMaxScaler.
# 3. Rellenar los valores nulos calculando la media de cada columna.
# 4. Incluir un modelo de Machine Learning al final del pipeline.
# 5. Normalizar la variable objetivo (target) utilizando MinMaxScaler.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 4.1 Paso 1: Preprocesamiento de los datos de entrada
#
# Agregamos todas las transformaciones que hemos desarrollado en la sección anterior en un Pipeline de Transformación de Datos.

# %%
from sklearn.base import BaseEstimator, TransformerMixin, OneToOneFeatureMixin


class PreprocessTransformer(BaseEstimator, TransformerMixin, OneToOneFeatureMixin):
    def __init__(self, location: tuple[int, int]):
        self.location = location

    def fit(self, X: pd.DataFrame, y: pd.Series | None = None):
        return self

    def transform(self, X: pd.DataFrame) -> pd.DataFrame:
        X = X.copy()  # avoid modifying incoming data
        X = add_date_columns(X)
        X = add_holiday_column(X)
        X = add_weather_columns(X, location=self.location)
        return X

# %%
item_df.head()
# Out:
#     familia  articulo fecha_venta          festivo  precio  cantidad  \
# 0  BOLLERIA      3960  2021-05-01             None   2.318     402.0
# 1  BOLLERIA      3960  2021-05-02  Día de la Madre   2.318     369.0
# 2  BOLLERIA      3960  2021-05-03   Día de la Cruz   2.318     228.0
# 3  BOLLERIA      3960  2021-05-04             None   2.318     237.0
# 4  BOLLERIA      3960  2021-05-05             None   2.318     288.0
#
#       importe  orden_articulo_familia  cantidad (t-4 weeks)  \
# 0  931.835995                       1                   NaN
# 1  855.341996                       1                   NaN
# 2  528.503994                       1                   NaN
# 3  549.365999                       1                   NaN
# 4  667.584000                       1                   NaN
#
#    cantidad (t-3 weeks)  cantidad (t-2 weeks)  cantidad (t-1 weeks)  \
# 0                   NaN                   NaN                   NaN
# 1                   NaN                   NaN                   NaN
# 2                   NaN                   NaN                   NaN
# 3                   NaN                   NaN                   NaN
# 4                   NaN                   NaN                   NaN
#
#    cantidad (t-6 days)  cantidad (t-5 days)  cantidad (t-4 days)  \
# 0                  NaN                  NaN                  NaN
# 1                  NaN                  NaN                  NaN
# 2                  NaN                  NaN                  NaN
# 3                  NaN                  NaN                  NaN
# 4                  NaN                  NaN                402.0
#
#    cantidad (t-3 days)  cantidad (t-2 days)  cantidad (t-1 days)
# 0                  NaN                  NaN                  NaN
# 1                  NaN                  NaN                402.0
# 2                  NaN                402.0                369.0
# 3                402.0                369.0                228.0
# 4                369.0                228.0                237.0

# %%
## Preprocesar datos
preprocessor = PreprocessTransformer(location=LOCATION)
preprocessed_df = preprocessor.transform(item_df)
preprocessed_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 730 entries, 0 to 729
# Data columns (total 35 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   familia                 730 non-null    object
#  1   articulo                730 non-null    int64
#  2   fecha_venta             730 non-null    datetime64[ns]
#  3   precio                  730 non-null    float64
#  4   cantidad                730 non-null    float64
#  5   importe                 730 non-null    float64
#  6   orden_articulo_familia  730 non-null    int64
#  7   cantidad (t-4 weeks)    702 non-null    float64
#  8   cantidad (t-3 weeks)    709 non-null    float64
#  9   cantidad (t-2 weeks)    716 non-null    float64
#  10  cantidad (t-1 weeks)    723 non-null    float64
#  11  cantidad (t-6 days)     724 non-null    float64
#  12  cantidad (t-5 days)     725 non-null    float64
#  13  cantidad (t-4 days)     726 non-null    float64
#  14  cantidad (t-3 days)     727 non-null    float64
#  15  cantidad (t-2 days)     728 non-null    float64
#  16  cantidad (t-1 days)     729 non-null    float64
#  17  day                     730 non-null    int32
#  18  month                   730 non-null    int32
#  19  year                    730 non-null    int32
#  20  dayofweek               730 non-null    int32
#  21  isWeekend               730 non-null    bool
#  22  isHoliday               730 non-null    bool
#  23  time                    730 non-null    datetime64[ns]
#  24  tavg                    730 non-null    Float64
#  25  tmin                    730 non-null    Float64
#  26  tmax                    730 non-null    Float64
#  27  prcp                    730 non-null    Float64
#  28  snow                    730 non-null    Float64
#  29  wdir                    730 non-null    Float64
#  30  wspd                    730 non-null    Float64
#  31  wpgt                    730 non-null    Float64
#  32  pres                    730 non-null    Float64
#  33  tsun                    730 non-null    Float64
#  34  isRaining               730 non-null    bool
# dtypes: Float64(10), bool(3), datetime64[ns](2), float64(13), int32(4), int64(2), object(1)
# memory usage: 186.1+ KB

# %% [markdown]
# ### 4.2 Paso 2: Eliminar los valores nulos
#
# En este paso simplemente rellenamos los valores nulos calculando la media de cada columna.

# %%
## rellenar valores nulos con la media
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer, make_column_selector

numerical_features = make_column_selector(dtype_include=[np.float64])


nans_remover = SimpleImputer(strategy="mean")

remove_nans_transformer = ColumnTransformer(
    transformers=[
        ("RemoveNans", nans_remover, numerical_features),
    ],
)

# %% [markdown]
# ### 4.3 Paso 3: Normalización de los datos de entrada
#
# Usamos `OneHotEncoder` para las variables categoricas y `MinMaxScaler`. para las variables numéricas.

# %%
## normalizar datos de entrada 
from sklearn.preprocessing import OneHotEncoder, MinMaxScaler
from sklearn.compose import ColumnTransformer, make_column_selector


categorical_features = make_column_selector(dtype_include=[object, np.int32])
numerical_features = make_column_selector(dtype_include=[np.float64])

ohe_encoder = OneHotEncoder(sparse_output=False, handle_unknown="ignore")
minmax_scaler = MinMaxScaler(feature_range=(0, 1))

encoders_transformer = ColumnTransformer(
    transformers=[
        ("OneHotEncoder", ohe_encoder, categorical_features),
        ("MinMaxScaler", minmax_scaler, numerical_features),
    ],
)

# %% [markdown]
# ### 4.4 Incluimos el modelo de Machine Learning
#
# Como nos encontramos en un problema de regresión, vamos a utilizar un modelo de regresión. En este caso, vamos a utilizar el modelo `LinearRegression` de Scikit-Learn.

# %%
## usar modelo de regresion
from sklearn.linear_model import LinearRegression


model = LinearRegression()
model
# Out:
# LinearRegression()

# %% [markdown]
# ### 4.5 Creamos el pipeline para las variables de entrada
#
# Agregamos los pasos anteriores al pipeline de transformación de datos de forma secuencial. El pipeline se encargará de aplicar las transformaciones a los datos de entrada y de entrenar el modelo.

# %%
## agregar pasos anteriores al pipeline
from sklearn.pipeline import Pipeline


input_pipeline = Pipeline(
    steps=[
        ("preprocessor", preprocessor),
        ("nan_remover", remove_nans_transformer),
        ("data_encoding", encoders_transformer),
        ("model", model),
    ]
)

input_pipeline.set_output(transform="pandas")
# Out:
# Pipeline(steps=[('preprocessor',
#                  PreprocessTransformer(location=(36.721477644071705,
#                                                  -4.363132134392174))),
#                 ('nan_remover',
#                  ColumnTransformer(transformers=[('RemoveNans', SimpleImputer(),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x713a3af4a900>)])),
#                 ('data_encoding',
#                  ColumnTransformer(transformers=[('OneHotEncoder',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse_output=False),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x713a3b4ff290>),
#                                                  ('MinMaxScaler',
#                                                   MinMaxScaler(),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x713a3b4ff4d0>)])),
#                 ('model', LinearRegression())])

# %% [markdown]
# ### 4.6 Paso 5: Normalizamos la variable objetivo
#
# En ultimo paso, usamos el mismo `OneHotEncoder` utilizado para los datos de entrada para codificar la variable objetivo (target), pero sin ajustarlo nuevamente. Esto asegura que la variable objetivo esté en el mismo formato que los datos de entrada, facilitando así la predicción y evaluación del modelo.

# %%
## codificar la variable objetivo para igualar en formato a los datos de entrada
from sklearn.compose import TransformedTargetRegressor


target_feature_scaler = MinMaxScaler(feature_range=(0,1))
final_pipeline = TransformedTargetRegressor(
    regressor=input_pipeline,
    transformer=target_feature_scaler,
)
final_pipeline
# Out:
# TransformedTargetRegressor(regressor=Pipeline(steps=[('preprocessor',
#                                                       PreprocessTransformer(location=(36.721477644071705,
#                                                                                       -4.363132134392174))),
#                                                      ('nan_remover',
#                                                       ColumnTransformer(transformers=[('RemoveNans',
#                                                                                        SimpleImputer(),
#                                                                                        <sklearn.compose._column_transformer.make_column_selector object at 0x713a3af4a900>)])),
#                                                      ('data_encoding',
#                                                       ColumnTransformer(transformers=[('OneHotEncoder',
#                                                                                        OneHotEncoder(handle_unknown='ignore',
#                                                                                                      sparse_output=False),
#                                                                                        <sklearn.compose._column_transformer.make_column_selector object at 0x713a3b4ff290>),
#                                                                                       ('MinMaxScaler',
#                                                                                        MinMaxScaler(),
#                                                                                        <sklearn.compose._column_transformer.make_column_selector object at 0x713a3b4ff4d0>)])),
#                                                      ('model',
#                                                       LinearRegression())]),
#                            transformer=MinMaxScaler())

# %% [markdown]
# ## 5. Entrenamos el modelo
#
# Utilizamos el pipeline creado anteriormente para entrenar el modelo. Marcamos el horizonte de tiempo del conjunto de test a 30 días. Esto significa que el modelo se evaluará con los datos de los últimos 30 días y se entrenará con los datos previos a dicho horizonte. Elegimos un solo producto para simplificar el proceso de entrenamiento y evaluación del modelo.

# %%
## realizar consulta del producto
PRODUCT_ID = 3960

item_mask = df["articulo"] == PRODUCT_ID
item_df = df[item_mask].copy()
item_df.head()
# Out:
#      familia  articulo fecha_venta          festivo  precio  cantidad  \
# 1   BOLLERIA      3960  2021-05-01             None   2.318     402.0
# 6   BOLLERIA      3960  2021-05-02  Día de la Madre   2.318     369.0
# 11  BOLLERIA      3960  2021-05-03   Día de la Cruz   2.318     228.0
# 16  BOLLERIA      3960  2021-05-04             None   2.318     237.0
# 21  BOLLERIA      3960  2021-05-05             None   2.318     288.0
#
#        importe  orden_articulo_familia
# 1   931.835995                       1
# 6   855.341996                       1
# 11  528.503994                       1
# 16  549.365999                       1
# 21  667.584000                       1

# %% [markdown]
# Guardamos la familia a la que pertenece el producto para guardarlo como tag en MLFlow

# %%
product_family = item_df["familia"].iloc[0]
product_family
# Out:
# 'BOLLERIA'

# %% [markdown]
# ### 5.1 Pequeña limpieza previa de los datos

# %% [markdown]
# Eliminamos las columnas que no vamos a utilizar

# %%
## eliminar columnas no utilizables
item_df.drop(columns=['importe', 'articulo', 'familia', 'orden_articulo_familia'], inplace=True)
item_df.head()
# Out:
#    fecha_venta          festivo  precio  cantidad
# 1   2021-05-01             None   2.318     402.0
# 6   2021-05-02  Día de la Madre   2.318     369.0
# 11  2021-05-03   Día de la Cruz   2.318     228.0
# 16  2021-05-04             None   2.318     237.0
# 21  2021-05-05             None   2.318     288.0

# %% [markdown]
# Reorganizamos el dataframe para que el orden de las fechas sea ascendente

# %%
## ordenar resultados
item_df.sort_values("fecha_venta", inplace=True)
item_df.reset_index(inplace=True, drop=True)
item_df.head()
# Out:
#   fecha_venta          festivo  precio  cantidad
# 0  2021-05-01             None   2.318     402.0
# 1  2021-05-02  Día de la Madre   2.318     369.0
# 2  2021-05-03   Día de la Cruz   2.318     228.0
# 3  2021-05-04             None   2.318     237.0
# 4  2021-05-05             None   2.318     288.0

# %% [markdown]
# Convertimos la serie a formato supervisado

# %%
## convertir a formato supervisado
item_df = series_to_supervised(item_df, daily_lag=6, weekly_lag=4)
item_df.head()
# Out:
#   fecha_venta          festivo  precio  cantidad  cantidad (t-4 weeks)  \
# 0  2021-05-01             None   2.318     402.0                   NaN
# 1  2021-05-02  Día de la Madre   2.318     369.0                   NaN
# 2  2021-05-03   Día de la Cruz   2.318     228.0                   NaN
# 3  2021-05-04             None   2.318     237.0                   NaN
# 4  2021-05-05             None   2.318     288.0                   NaN
#
#    cantidad (t-3 weeks)  cantidad (t-2 weeks)  cantidad (t-1 weeks)  \
# 0                   NaN                   NaN                   NaN
# 1                   NaN                   NaN                   NaN
# 2                   NaN                   NaN                   NaN
# 3                   NaN                   NaN                   NaN
# 4                   NaN                   NaN                   NaN
#
#    cantidad (t-6 days)  cantidad (t-5 days)  cantidad (t-4 days)  \
# 0                  NaN                  NaN                  NaN
# 1                  NaN                  NaN                  NaN
# 2                  NaN                  NaN                  NaN
# 3                  NaN                  NaN                  NaN
# 4                  NaN                  NaN                402.0
#
#    cantidad (t-3 days)  cantidad (t-2 days)  cantidad (t-1 days)
# 0                  NaN                  NaN                  NaN
# 1                  NaN                  NaN                402.0
# 2                  NaN                402.0                369.0
# 3                402.0                369.0                228.0
# 4                369.0                228.0                237.0

# %% [markdown]
# ### 5.2 Dividimos en conjuntos de entrenamiento y test

# %%
## dividir en train y test
horizont = datetime(2023,4,19)


df_train = item_df.loc[item_df["fecha_venta"]<horizont]
df_test = item_df.loc[item_df["fecha_venta"]>=horizont]


X_train = df_train.drop(columns=["cantidad"])
y_train = df_train["cantidad"]
X_test = df_test.drop(columns=["cantidad"])
y_test = df_test["cantidad"]

# %% [markdown]
# ### 5.3 Iniciar el servidor de MLFlow
#
# - 👉 Lanzar un servidor MLFlow local
# - 👉 Conectarse al servidor MLFlow local
# - 👉 Establecer el experimento deseado
# - 👉 Habilitar el autologging de MLFlow para sklearn

# %%
## Configurar MLFlow
# %pip install mlflow

import mlflow

# Connect to MLFlow server hosted locally
MLFLOW_EXPERIMENT_NAME = "Datathon V"
MLFLOW_TRACKING_URI = "http://localhost:5000"


mlflow.set_tracking_uri(MLFLOW_TRACKING_URI)
mlflow.set_experiment(MLFLOW_EXPERIMENT_NAME)
mlflow.sklearn.autolog()
# Out:
# Requirement already satisfied: mlflow in /workspaces/finalmad/.venv/lib/python3.12/site-packages (3.2.0)
# Requirement already satisfied: mlflow-skinny==3.2.0 in /workspaces/finalmad/.venv/lib/python3.12/site-packages (from mlflow) (3.2.0)
# Requirement already satisfied: mlflow-tracing==3.2.0 in /workspaces/finalmad/.venv/lib/python3.12/site-packages (from mlflow) (3.2.0)
# Requirement already satisfied: Flask<4 in /workspaces/finalmad/.venv/lib/python3.12/site-packages (from mlflow) (3.1.1)
# Requirement already satisfied: alembic!=1.10.0,<2 in /workspaces/finalmad/.venv/lib/python3.12/site-packages (from mlflow) (1.16.4)
# Requirement already satisfied: docker<8,>=4.0.0 in /workspaces/finalmad/.venv/lib/python3.12/site-packages (from mlflow) (7.1.0)
# Requirement already satisfied: graphene<4 in /workspaces/finalmad/.venv/lib/python3.12/site-packages (from mlflow) (3.4.3)
# Requirement already satisfied: gunicorn<24 in /workspaces/finalmad/.venv/lib/python3.12/site-packages (from mlflow) (23.0.0)
# Requirement already satisfied: matplotlib<4 in /workspaces/finalmad/.venv/lib/python3.12/site-packages (from mlflow) (3.10.3)
# Requirement already satisfied: numpy<3 in /workspaces/finalmad/.venv/lib/python3.12/site-packages (from mlflow) (2.3.2)
# Requirement already satisfied: pandas<3 in /workspaces/finalmad/.venv/lib/python3.12/site-packages (from mlflow) (2.3.1)
# Requirement already satisfied: pyarrow<22,>=4.0.0 in /workspaces/finalmad/.venv/lib/python3.12/site-packages (from mlflow) (21.0.0)
# Requirement already satisfied: scikit-learn<2 in /workspaces/finalmad/.venv/lib/python3.12/site-packages (from mlflow) (1.7.1)
# Requirement already satisfied: scipy<2 in /workspaces/finalmad/.venv/lib/python3.12/site-packages (from mlflow) (1.16.1)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in /workspaces/finalmad/.venv/lib/python3.12/site-packages (from mlflow) (2.0.42)
# Requirement already satisfied: cachetools<7,>=5.0.0 in /workspaces/finalmad/.venv/lib/python3.12/site-packages (from mlflow-skinny==3.2.0->mlflow) (5.5.2)
# Requirement already satisfied: click<9,>=7.0 in /workspaces/finalmad/.venv/lib/python3.12/site-packages (from mlflow-skinny==3.2.0->mlflow) (8.2.1)
# Requirement already satisfied: cloudpickle<4 in /workspaces/finalmad/.venv/lib/python3.12/site-packages (from mlflow-skinny==3.2.0->mlflow) (3.1.1)
# Requirement already satisfied: databricks-sdk<1,>=0.20.0 in /workspaces/finalmad/.venv/lib/python3.12/site-packages (from mlflow-skinny==3.2.0->mlflow) (0.63.0)
# Requirement already satisfied: fastapi<1 in /workspaces/finalmad/.venv/lib/python3.12/site-packages (from mlflow-skinny==3.2.0->mlflow) (0.116.1)
# Requirement already satisfied: gitpython<4,>=3.1.9 in /workspaces/finalmad/.venv/lib/python3.12/site-packages (from mlflow-skinny==3.2.0->mlflow) (3.1.45)
# Requirement already satisfied: importlib_metadata!=4.7.0,<9,>=3.7.0 in /workspaces/finalmad/.venv/lib/python3.12/site-packages (from mlflow-skinny==3.2.0->mlflow) (8.7.0)
# Requirement already satisfied: opentelemetry-api<3,>=1.9.0 in /workspaces/finalmad/.venv/lib/python3.12/site-packages (from mlflow-skinny==3.2.0->mlflow) (1.36.0)
# Requirement already satisfied: opentelemetry-sdk<3,>=1.9.0 in /workspaces/finalmad/.venv/lib/python3.12/site-packages (from mlflow-skinny==3.2.0->mlflow) (1.36.0)
# Requirement already satisfied: packaging<26 in /workspaces/finalmad/.venv/lib/python3.12/site-packages (from mlflow-skinny==3.2.0->mlflow) (25.0)
# Requirement already satisfied: protobuf<7,>=3.12.0 in /workspaces/finalmad/.venv/lib/python3.12/site-packages (from mlflow-skinny==3.2.0->mlflow) (6.32.0)
# Requirement already satisfied: pydantic<3,>=1.10.8 in /workspaces/finalmad/.venv/lib/python3.12/site-packages (from mlflow-skinny==3.2.0->mlflow) (2.11.7)
# Requirement already satisfied: pyyaml<7,>=5.1 in /workspaces/finalmad/.venv/lib/python3.12/site-packages (from mlflow-skinny==3.2.0->mlflow) (6.0.2)
# Requirement already satisfied: requests<3,>=2.17.3 in /workspaces/finalmad/.venv/lib/python3.12/site-packages (from mlflow-skinny==3.2.0->mlflow) (2.32.5)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in /workspaces/finalmad/.venv/lib/python3.12/site-packages (from mlflow-skinny==3.2.0->mlflow) (0.5.3)
# Requirement already satisfied: typing-extensions<5,>=4.0.0 in /workspaces/finalmad/.venv/lib/python3.12/site-packages (from mlflow-skinny==3.2.0->mlflow) (4.14.1)
# Requirement already satisfied: uvicorn<1 in /workspaces/finalmad/.venv/lib/python3.12/site-packages (from mlflow-skinny==3.2.0->mlflow) (0.35.0)
# Requirement already satisfied: Mako in /workspaces/finalmad/.venv/lib/python3.12/site-packages (from alembic!=1.10.0,<2->mlflow) (1.3.10)
# Requirement already satisfied: google-auth~=2.0 in /workspaces/finalmad/.venv/lib/python3.12/site-packages (from databricks-sdk<1,>=0.20.0->mlflow-skinny==3.2.0->mlflow) (2.40.3)
# Requirement already satisfied: urllib3>=1.26.0 in /workspaces/finalmad/.venv/lib/python3.12/site-packages (from docker<8,>=4.0.0->mlflow) (2.5.0)
# Requirement already satisfied: starlette<0.48.0,>=0.40.0 in /workspaces/finalmad/.venv/lib/python3.12/site-packages (from fastapi<1->mlflow-skinny==3.2.0->mlflow) (0.47.2)
# Requirement already satisfied: blinker>=1.9.0 in /workspaces/finalmad/.venv/lib/python3.12/site-packages (from Flask<4->mlflow) (1.9.0)
# Requirement already satisfied: itsdangerous>=2.2.0 in /workspaces/finalmad/.venv/lib/python3.12/site-packages (from Flask<4->mlflow) (2.2.0)
# Requirement already satisfied: jinja2>=3.1.2 in /workspaces/finalmad/.venv/lib/python3.12/site-packages (from Flask<4->mlflow) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in /workspaces/finalmad/.venv/lib/python3.12/site-packages (from Flask<4->mlflow) (3.0.2)
# Requirement already satisfied: werkzeug>=3.1.0 in /workspaces/finalmad/.venv/lib/python3.12/site-packages (from Flask<4->mlflow) (3.1.3)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /workspaces/finalmad/.venv/lib/python3.12/site-packages (from gitpython<4,>=3.1.9->mlflow-skinny==3.2.0->mlflow) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in /workspaces/finalmad/.venv/lib/python3.12/site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==3.2.0->mlflow) (5.0.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /workspaces/finalmad/.venv/lib/python3.12/site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.2.0->mlflow) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /workspaces/finalmad/.venv/lib/python3.12/site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.2.0->mlflow) (4.9.1)
# Requirement already satisfied: graphql-core<3.3,>=3.1 in /workspaces/finalmad/.venv/lib/python3.12/site-packages (from graphene<4->mlflow) (3.2.6)
# Requirement already satisfied: graphql-relay<3.3,>=3.1 in /workspaces/finalmad/.venv/lib/python3.12/site-packages (from graphene<4->mlflow) (3.2.0)
# Requirement already satisfied: python-dateutil<3,>=2.7.0 in /workspaces/finalmad/.venv/lib/python3.12/site-packages (from graphene<4->mlflow) (2.9.0.post0)
# Requirement already satisfied: zipp>=3.20 in /workspaces/finalmad/.venv/lib/python3.12/site-packages (from importlib_metadata!=4.7.0,<9,>=3.7.0->mlflow-skinny==3.2.0->mlflow) (3.23.0)
# Requirement already satisfied: contourpy>=1.0.1 in /workspaces/finalmad/.venv/lib/python3.12/site-packages (from matplotlib<4->mlflow) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /workspaces/finalmad/.venv/lib/python3.12/site-packages (from matplotlib<4->mlflow) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /workspaces/finalmad/.venv/lib/python3.12/site-packages (from matplotlib<4->mlflow) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /workspaces/finalmad/.venv/lib/python3.12/site-packages (from matplotlib<4->mlflow) (1.4.8)
# Requirement already satisfied: pillow>=8 in /workspaces/finalmad/.venv/lib/python3.12/site-packages (from matplotlib<4->mlflow) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /workspaces/finalmad/.venv/lib/python3.12/site-packages (from matplotlib<4->mlflow) (3.2.3)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.57b0 in /workspaces/finalmad/.venv/lib/python3.12/site-packages (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==3.2.0->mlflow) (0.57b0)
# Requirement already satisfied: pytz>=2020.1 in /workspaces/finalmad/.venv/lib/python3.12/site-packages (from pandas<3->mlflow) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /workspaces/finalmad/.venv/lib/python3.12/site-packages (from pandas<3->mlflow) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /workspaces/finalmad/.venv/lib/python3.12/site-packages (from pydantic<3,>=1.10.8->mlflow-skinny==3.2.0->mlflow) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /workspaces/finalmad/.venv/lib/python3.12/site-packages (from pydantic<3,>=1.10.8->mlflow-skinny==3.2.0->mlflow) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /workspaces/finalmad/.venv/lib/python3.12/site-packages (from pydantic<3,>=1.10.8->mlflow-skinny==3.2.0->mlflow) (0.4.1)
# Requirement already satisfied: six>=1.5 in /workspaces/finalmad/.venv/lib/python3.12/site-packages (from python-dateutil<3,>=2.7.0->graphene<4->mlflow) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /workspaces/finalmad/.venv/lib/python3.12/site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.2.0->mlflow) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /workspaces/finalmad/.venv/lib/python3.12/site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.2.0->mlflow) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /workspaces/finalmad/.venv/lib/python3.12/site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.2.0->mlflow) (2025.8.3)
# Requirement already satisfied: pyasn1>=0.1.3 in /workspaces/finalmad/.venv/lib/python3.12/site-packages (from rsa<5,>=3.1.4->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.2.0->mlflow) (0.6.1)
# Requirement already satisfied: joblib>=1.2.0 in /workspaces/finalmad/.venv/lib/python3.12/site-packages (from scikit-learn<2->mlflow) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /workspaces/finalmad/.venv/lib/python3.12/site-packages (from scikit-learn<2->mlflow) (3.6.0)
# Requirement already satisfied: greenlet>=1 in /workspaces/finalmad/.venv/lib/python3.12/site-packages (from sqlalchemy<3,>=1.4.0->mlflow) (3.2.3)
# Requirement already satisfied: anyio<5,>=3.6.2 in /workspaces/finalmad/.venv/lib/python3.12/site-packages (from starlette<0.48.0,>=0.40.0->fastapi<1->mlflow-skinny==3.2.0->mlflow) (4.10.0)
# Requirement already satisfied: sniffio>=1.1 in /workspaces/finalmad/.venv/lib/python3.12/site-packages (from anyio<5,>=3.6.2->starlette<0.48.0,>=0.40.0->fastapi<1->mlflow-skinny==3.2.0->mlflow) (1.3.1)
# Requirement already satisfied: h11>=0.8 in /workspaces/finalmad/.venv/lib/python3.12/site-packages (from uvicorn<1->mlflow-skinny==3.2.0->mlflow) (0.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### 5.4 Entrenamos y evaluamos el modelo
#
# La siguiente sección consiste en entrenar y evaluar el modelo. Veremos como al utilizar el pipeline se simplifica el proceso de entrenamiento y evaluación del modelo.
#
# 💡 El autolog registrará automáticamente las métricas y el modelo

# %%
## entrena y evalua modelo
from sklearn import metrics

mlflow.end_run()  # End any previous run if active

with mlflow.start_run() as run:

    mlflow.set_tag("product_family", product_family)
    mlflow.set_tag("product_id", PRODUCT_ID)

    final_pipeline.fit(X_train, y_train)
    y_pred = final_pipeline.predict(X_test)

    mae = metrics.mean_absolute_error(y_test, y_pred)
    mlflow.log_metric('mae', mae)
# Out:
# 🏃 View run unequaled-boar-995 at: http://localhost:5000/#/experiments/593696523720765029/runs/3411714cfba04ba19eb07f986b9fa1d5
# 🧪 View experiment at: http://localhost:5000/#/experiments/593696523720765029

# %% [markdown]
# ### 5.5 Creamos graficos de resultados
#
# Mostramos la diferencia entre las ventas reales y las predicciones

# %%
import seaborn as sns
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(6, 6))
ax.set_title("Predicted Sales vs Actual Sales")
ax.set_xlabel("Predicted Sales")
ax.set_ylabel("Actual Sales")

sns.scatterplot(x=y_pred, y=y_test, ax=ax, label="Predicted Sales")
sns.lineplot(x=y_test, y=y_test, color="red", ax=ax, label="Real Sales")

# Save to MLFlow last run
fig_path = 'predictions_vs_ground_truth.png'
plt.savefig(fig_path)
mlflow.log_artifact(fig_path)

# %% [markdown]
# Mostramos la diferencia entre las ventas reales y las predicciones a lo largo del tiempo

# %%
fig, ax = plt.subplots(figsize=(12, 6))

ax.set_title("Predicted Sales vs Actual Sales")
ax.set_xlabel("Date")
ax.set_ylabel("Sales")
ax.set_xticklabels(df_test["fecha_venta"], rotation=45)

dates = df_test["fecha_venta"].astype(str)
sns.lineplot(x=dates, y=y_pred, label="Predicted Sales")
sns.lineplot(x=dates, y=y_test, label="Real Sales")

# Save to MLFlow last run
fig_path = 'predictions_vs_ground_truth_timeline.png'
plt.savefig(fig_path)
mlflow.log_artifact(fig_path)
# Out:
# UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.

# %% [markdown]
# ## 6. Productivización del modelo
#
# 👇 Utiliza tus conocimientos de MLOps para desplegar un modelo registrado en MLFlow. Si todo ha ido correctamente deberias ver unos logs similares a estos:
#
# ```bash
# INFO:     Uvicorn running on http://127.0.0.1:8000 (Press CTRL+C to quit)
# INFO:     Started parent process [15]
# INFO:     Started server process [20]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# ```

# %% [markdown]
# ## 7. Haz peticiones al modelo
#
# Una vez has desplegado el modelo, puedes hacer peticiones al mismo. Aplica los conocimientos de comunicación entre servicios que hemos visto en clase para hacer una petición al modelo. Enviale el conjunto de test y obtendrás las predicciones del modelo.
#
# - ⚠️ Importante: el campo `fecha_venta` debes convertirlo a `string` previamente para que pueda ser enviado al modelo.
# - ⚠️ Importante: guarda las predicciones en una variable `predictions` para que puedas utilizarlas posteriormente.

# %%
# 👇 add your code here

# %% [markdown]
# ## 8. Sube tus resultados a la base de datos
#
# Sube las predicciones devueltas por el modelo desplegado a la base de datos. De esta forma podras utilizarlos en Tableau, PowerBI, etc. Primero creamos el dataframe que subiremos a la base de datos. Este dataframe contendrá las siguientes columnas:
#
# | **Columna**      | **Descripción**                                  |
# |------------------|--------------------------------------------------|
# | `fecha`          | Fecha de la predicción                           |
# | `cantidad`       | Ventas predichas por el modelo                   |
# | `articulo`       | ID del producto                                  |
# | `familia`        | Familia del producto                             |

# %%
df_test
# Out:
#     fecha_venta festivo  precio  cantidad  cantidad (t-4 weeks)  \
# 718  2023-04-19    None   3.273     183.0                 216.0
# 719  2023-04-20    None   3.273     222.0                 270.0
# 720  2023-04-21    None   3.273     216.0                 150.0
# 721  2023-04-22    None   3.273     297.0                 309.0
# 722  2023-04-23    None   3.273     336.0                 321.0
# 723  2023-04-24    None   3.273     204.0                 183.0
# 724  2023-04-25    None   3.273     246.0                 156.0
# 725  2023-04-26    None   3.273     162.0                 207.0
# 726  2023-04-27    None   3.273     216.0                 192.0
# 727  2023-04-28    None   3.273     183.0                 216.0
# 728  2023-04-29    None   3.273     249.0                 210.0
# 729  2023-04-30    None   3.273     330.0                 315.0
#
#      cantidad (t-3 weeks)  cantidad (t-2 weeks)  cantidad (t-1 weeks)  \
# 718                 207.0                 231.0                 183.0
# 719                 192.0                 327.0                 138.0
# 720                 216.0                 330.0                 204.0
# 721                 210.0                 267.0                 276.0
# 722                 315.0                 315.0                 333.0
# 723                 210.0                 213.0                 192.0
# 724                 204.0                 153.0                 234.0
# 725                 231.0                 183.0                 183.0
# 726                 327.0                 138.0                 222.0
# 727                 330.0                 204.0                 216.0
# 728                 267.0                 276.0                 297.0
# 729                 315.0                 333.0                 336.0
#
#      cantidad (t-6 days)  cantidad (t-5 days)  cantidad (t-4 days)  \
# 718                138.0                204.0                276.0
# 719                204.0                276.0                333.0
# 720                276.0                333.0                192.0
# 721                333.0                192.0                234.0
# 722                192.0                234.0                183.0
# 723                234.0                183.0                222.0
# 724                183.0                222.0                216.0
# 725                222.0                216.0                297.0
# 726                216.0                297.0                336.0
# 727                297.0                336.0                204.0
# 728                336.0                204.0                246.0
# 729                204.0                246.0                162.0
#
#      cantidad (t-3 days)  cantidad (t-2 days)  cantidad (t-1 days)
# 718                333.0                192.0                234.0
# 719                192.0                234.0                183.0
# 720                234.0                183.0                222.0
# 721                183.0                222.0                216.0
# 722                222.0                216.0                297.0
# 723                216.0                297.0                336.0
# 724                297.0                336.0                204.0
# 725                336.0                204.0                246.0
# 726                204.0                246.0                162.0
# 727                246.0                162.0                216.0
# 728                162.0                216.0                183.0
# 729                216.0                183.0                249.0

# %%
dates = df_test["fecha_venta"].tolist()
predictions = y_pred

# Create a dataframe with the data to store
df_article_prediction = pd.DataFrame({
    "fecha": dates,
    "cantidad": predictions,
    "articulo": [PRODUCT_ID] * len(predictions),  # repeat the article for each date
    "familia": [product_family] * len(predictions),  # repeat the family for each date
})

df_article_prediction.head(5)
# Out:
#        fecha    cantidad  articulo   familia
# 0 2023-04-19  210.054475      3960  BOLLERIA
# 1 2023-04-20  215.770949      3960  BOLLERIA
# 2 2023-04-21  230.256587      3960  BOLLERIA
# 3 2023-04-22  252.956264      3960  BOLLERIA
# 4 2023-04-23  295.314118      3960  BOLLERIA

# %% [markdown]
# Subimos los resultados.

# %%
# Database credentials
DATABASE = "sandbox"
NAME = "kikehr"  # ‼️ Cambia esta variable por tu nombre. 

table_name = f"Materials_Prediction_Group_{NAME}"

# Connect to the database
db = DatabaseConnection(DB_USERNAME, DB_PASSWORD, database=DATABASE)
db.insert_dataframe(df_article_prediction, table_name)
